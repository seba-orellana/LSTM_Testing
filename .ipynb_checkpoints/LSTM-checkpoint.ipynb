# %%
# !pip uninstall numpy
import pandas as pd
import numpy as np
import seaborn as sns
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
# Out:
# Found existing installation: numpy 2.2.6
# Uninstalling numpy-2.2.6:
#   Would remove:
#     /home/sebastian/.local/bin/f2py
#     /home/sebastian/.local/bin/numpy-config
#     /home/sebastian/.local/lib/python3.10/site-packages/numpy-2.2.6.dist-info/*
#     /home/sebastian/.local/lib/python3.10/site-packages/numpy.libs/libgfortran-040039e1-0352e75f.so.5.0.0
#     /home/sebastian/.local/lib/python3.10/site-packages/numpy.libs/libquadmath-96973f99-934c22de.so.0.0.0
#     /home/sebastian/.local/lib/python3.10/site-packages/numpy.libs/libscipy_openblas64_-56d6093b.so
#     /home/sebastian/.local/lib/python3.10/site-packages/numpy/*
# Proceed (Y/n)?

# %%
df = pd.read_csv('LSTM-Multivariate_pollution.csv', parse_dates=['date'])
df
# Out:
#                      date  pollution  dew  temp   press wnd_dir  wnd_spd  \
# 0     2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79
# 1     2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68
# 2     2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57
# 3     2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36
# 4     2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25
# ...                   ...        ...  ...   ...     ...     ...      ...
# 43795 2014-12-31 19:00:00        8.0  -23  -2.0  1034.0      NW   231.97
# 43796 2014-12-31 20:00:00       10.0  -22  -3.0  1034.0      NW   237.78
# 43797 2014-12-31 21:00:00       10.0  -22  -3.0  1034.0      NW   242.70
# 43798 2014-12-31 22:00:00        8.0  -22  -4.0  1034.0      NW   246.72
# 43799 2014-12-31 23:00:00       12.0  -21  -3.0  1034.0      NW   249.85
#
#        snow  rain
# 0         0     0
# 1         0     0
# 2         0     0
# ...

# %%
# Establecer que ahora el indice seran los timestamp en lugar de numeros ordenados
df.index = pd.to_datetime(df['date'])

# %%
# Primer grafica de los datos de contaminacion
# Cantidad de particulas <= 2,5 micrometros por cada gramo/m3
pollution = df['pollution']
pollution.plot()
# Out:
# <Axes: xlabel='date'>

# %%
# Feature Engineering

wind_to_int = {
    'SE': 1,
    'NW': 2,
    'cv': 3,
    'NE': 4
}

df['wnd_dir'] = df['wnd_dir'].map(wind_to_int) 
df
# Out:
#                      date  pollution  dew  temp   press  wnd_dir  wnd_spd  \
# 0     2010-01-02 00:00:00      129.0  -16  -4.0  1020.0        1     1.79
# 1     2010-01-02 01:00:00      148.0  -15  -4.0  1020.0        1     2.68
# 2     2010-01-02 02:00:00      159.0  -11  -5.0  1021.0        1     3.57
# 3     2010-01-02 03:00:00      181.0   -7  -5.0  1022.0        1     5.36
# 4     2010-01-02 04:00:00      138.0   -7  -5.0  1022.0        1     6.25
# ...                   ...        ...  ...   ...     ...      ...      ...
# 43795 2014-12-31 19:00:00        8.0  -23  -2.0  1034.0        2   231.97
# 43796 2014-12-31 20:00:00       10.0  -22  -3.0  1034.0        2   237.78
# 43797 2014-12-31 21:00:00       10.0  -22  -3.0  1034.0        2   242.70
# 43798 2014-12-31 22:00:00        8.0  -22  -4.0  1034.0        2   246.72
# 43799 2014-12-31 23:00:00       12.0  -21  -3.0  1034.0        2   249.85
#
#        snow  rain
# 0         0     0
# 1         0     0
# 2         0     0
# ...

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.7 MB/s  0:00:007.2 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 6.9 MB/s  0:00:007.1 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 6.2 MB/s  0:00:006.5 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [keras]━━━━━ 5/6 [keras][absl-py]
# ...
